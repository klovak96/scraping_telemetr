# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %%
import requests
from bs4 import BeautifulSoup


login_url = "https://telemetr.me/login/"  

login_data = {
    'login[email]': 'Klovak.top@yandex.ru',  
    'login[password]': 'Klovak.top@yandex.ru', 
    'recaptcha_response': '03AFcWeA5Qtim3ErT75AJu-7a8TbdsuCMZrl7vKvypPZYrQTxEk3k9nQkb3HGXrkKHb77RKU5LOybYdybw2eXdqJNczDHsXqKqixoKJEeOpOd-qldx1dj-9-ywWpEqe2rSdjjAe83d9qZwsyQdph58Cu_iTvp6pwqbQ3-1F5X0tAdW552EOPveIpOFnZeeq6mgicH9yCVbK5IqJZnpdhM0ub0o5FiwovLEgDAl6q1Fu3WqdWHD235Kmf8vNGMF1HaEtwUiFH2KyJEp0o83J3KsCzU4B8OGcycAsNwOR47JS-ls1N9Lu4cgwCdUUayOpOKV4no_7vndNzJ8W1vuic09rSLMnd20kaMDeP2QcB-RPkrqJ256Ze3WsDK4x9YFOKrBs4I_0AGlbGprfZmfZ9q-KrjIlnFEDYPEZWuzRjOCdESwYewTqTIPiBCTTXfa25xOY0B6EishrJzMyngEa3-ipKzA7q-n6zPq-dR4SYAEHmYTmz1bmYEdOJIjQlbtanm6X_nCJMGA9Xpxb5Ruf-3W_OQNuzF-9IzvFGlxWwzYp3BM4iVUoL5FQEBFwl06SN-LgPmO1uxC2Xq5tTEhISVhm_3_BCmBsiNCiLWmrHjm8Y5WU36p4DOIJ8gsCo2h9wVRfO-akqkHMUWW1xUJjmfWoEUSqXcHjlujqWp5rn-bSTfzbEpSo8n-Of6QDZBKvLOg0VM7VSP_wRkKMsvpDpOHI8MSpfcPSQSsKZBcWHsNUj2iFOB-LxnxkmOfU2D4DnuYzB4sh_xlAt-HZTJUp-Ec88xSoxfbEPKC3ff9u3F5cXI7sDmpP1U4jkenEM7uITRL4yAP0LTo1jLv',
    'do_login': ''
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Referer': 'https://telemetr.me/login/',
}

session = requests.Session()
response = session.post(login_url, data=login_data, headers=headers)

from_tg_url = input()
response_first = session.get(from_tg_url)
soup = BeautifulSoup(response_first.text, 'html.parser')


if response_first.ok:
    print("Авторизация успешна!")
else:
    print("Ошибка авторизации.")
# Out:
#  https://telemetr.me/profile/confirm/?confirm=79bef9619bca7dc67a999eee9f8a665d
# Авторизация успешна!

# %%
def get_tg_admins(min_sub, max_sub, pages=1,category = 'Юмор', format_back = 'null'):
    base_url = 'https://telemetr.me/'
    res=[]
    
    for p in range(1,pages + 1):
        response = session.get(f'{base_url}channels/cat/{category}/?order_column=participants_count&order_direction=DESC&page={p}&participants_from={min_sub}&participants_to={max_sub}&lang_ru=1&lang_uz=0&channel_type=opened&moderate=all&verified=all&detailed_bot_added=all&lang_code=ru')
        #'https://telemetr.me/channels/cat/Юмор/?about=%27%40%27&participants_from=300&participants_to=3000&channel_type=opened&lang_code=ru&detailed_bot_added=all'
        soup = BeautifulSoup(response.text)
        tables = soup.find_all('tr', class_ = ['tr_even','tr_odd'])

        for table in tables:
            #time.sleep(0.2)
            
            try:
                title = table.find('a', 'kt-ch-title').text
            except:
                continue
                
            try:
                subscribers = table.find('span', 'kt-number kt-font-brand text-cursor').text            
                subscribers = re.search('\d.\d{3}', subscribers).group().replace("'", "")
            except:
                continue 
                
            
            channel_link = base_url + table.find('a', 'kt-ch-title').get('href')[1:]
            channel_info = session.get(channel_link)
            channel_info.encoding = 'utf-8' 
            soup_info = BeautifulSoup(channel_info.text)
            
            try:
                a = soup_info.find('div', 'kt-widget__desc t_long').find_all('a')
                admins = []
                for link in a:
                    admin = link.get('href')
                    if re.search('^https://t\.me/(?!\+)(?!.*[bB][oO][tT]$).*', admin):
                        admins.append(admin)
                if len(admins) == 0:
                    continue
            except:
                continue
                
            try:
                link = soup_info.find('a', 'kt-widget__username').get('href')
                #link = re.search('@\w*', link).group()
            except:
                continue    
            
            
            try:
                description = soup_info.find('div', 'kt-widget__desc t_long').text 
                description = re.sub(r'^\s+', '', description)
            except:
                continue 
                        

            sub_month = soup_info.find('div', id='new_week').find('span', class_ = ['kt-number kt-font-success', 'kt-number kt-font-danger']).text 
            
            
                
            res.append({'title': title, 'link': link, 'subscribers': subscribers, 'sub_month': sub_month,'description': description, 'admins': '\n'.join(admins)})
            
    res_df = pd.DataFrame(res)
    
    if format_back == 'csv':
        res_df.to_csv('results.csv', index=False)
    elif format_back == 'excel':
        res_df.to_excel('results.xlsx', sheet_name='Admins List', index=False)
        
    return res_df

# %%
result = get_tg_admins(300,3000,pages = 5,format_back = 'excel')
result.head()
# Out:
#                        title                           link subscribers  \
# 0  загадочные обстоятельства             https://t.me/zobst        2930
# 1           АКАДЕМИЯ СМЕХА ?  https://t.me/academylaughtoff        2901
# 2                 IQ boost ?          https://t.me/iq_boost        2894
# 3         нетолерантные мемы   https://t.me/netolerantmemes        2890
# 4                   bruh.mp4        https://t.me/bruhvideos        2837
#
#   sub_month                                        description  \
# 0       -60  \n\t\t\t\t\t\t\t\t\t\t\t\tСтрашно, очень страш...
# 1       -57  \n\t\t\t\t\t\t\t\t\t\t\t\tУгарные мемы 😂 ,треш...
# 2       -37  \n\t\t\t\t\t\t\t\t\t\t\t\t🧩 Solve puzzles and ...
# 3       -90  \n\t\t\t\t\t\t\t\t\t\t\t\tмы за равные права д...
# 4       -40  \n\t\t\t\t\t\t\t\t\t\t\t\tShitty vidеоs. Barel...
#
#                                            admins
# 0  https://t.me/allldavis\nhttps://t.me/merlegraf
# 1                         https://t.me/academytg1
# 2                            https://t.me/vikatom
# 3                        https://t.me/dirtycringe
# 4                         https://t.me/plutocargo

# %%
                        
def test(min_sub, max_sub, pages=1,category = 'Юмор'):
    base_url = 'https://telemetr.me/'
    res=[]
    
    for p in range(1,pages + 1):
        response = session.get(f'{base_url}channels/cat/{category}/?order_column=participants_count&order_direction=DESC&page={p}&participants_from={min_sub}&participants_to={max_sub}&lang_ru=1&lang_uz=0&channel_type=opened&moderate=all&verified=all&detailed_bot_added=all&lang_code=ru')
        #'https://telemetr.me/channels/cat/Юмор/?about=%27%40%27&participants_from=300&participants_to=3000&channel_type=opened&lang_code=ru&detailed_bot_added=all'
        soup = BeautifulSoup(response.text)
        tables = soup.find_all('tr', class_ = ['tr_even','tr_odd'])

        for table in tables:
            #time.sleep(0.2)
            
            try:
                title = table.find('a', 'kt-ch-title').text
            except:
                continue
                
            
            channel_link = base_url + table.find('a', 'kt-ch-title').get('href')[1:]
            channel_info = session.get(channel_link)
            channel_info.encoding = 'utf-8' 

            soup_info = BeautifulSoup(channel_info.text)
            
            
            
            #br = soup_info.find('div', 'kt-widget__desc t_long').find_all('br')
            #print(br)
            #for b in br:
            #    a = b.find_all('a')
            #    for i in a:
            #        print(i.text)
            
            try:
                a = soup_info.find('div', 'kt-widget__desc t_long').find_all('a')
                admins = []
                for link in a:
                    admin = link.get('href')
                    if re.search('^https://t\.me/(?!\+)(?!.*[bB][oO][tT]$).*', admin):
                        admins.append(admin)
                if len(admins) == 0:
                    continue
            except:
                continue
            
                
            res.append({'title': title, 'admins': '\n'.join(admins)})
            
    res_df = pd.DataFrame(res)
    return res_df

results = test(300,3000,pages = 1)
results.to_excel('results.xlsx', sheet_name='Admins List', index=False)

# %%
protected_url = "https://telemetr.me/channels/cat/Юмор/?order_column=participants_count&order_direction=DESC&page=2&participants_from=500&participants_to=3000&lang_ru=1&lang_uz=0&channel_type=all&moderate=all&verified=all&detailed_bot_added=all&lang_code=any"
response = session.get(protected_url)
soup = BeautifulSoup(response.text, 'html.parser')
#print(soup)
# Out:
# <!DOCTYPE html>
#  <html lang="en"> <head> <meta charset="utf-8"/> <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/> <link href="/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/> <link href="/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/> <link href="/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/> <link href="/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/> <link href="/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/> <link href="/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/> <link href="/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/> <link href="/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/> <link href="/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/> <link href="/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/> <link href="/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/> <link href="/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/> <link href="/favicons/manifest.json" rel="manifest"/> <link href="/favicon.ico" rel="icon" type="image/x-icon"/> <meta content="#ffffff" name="msapplication-TileColor"/> <meta content="/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/> <meta content="#ffffff" name="theme-color"/> <meta content="https://telemetr.me/favicons/apple-touch-icon-180x180.png" property="vk:image"> <meta content="https://telemetr.me/favicons/apple-touch-icon-180x180.png" property="og:image"> <meta content="https://telemetr.me/favicons/apple-touch-icon-180x180.png" property="twitter:image"> <meta content="Телеметр - аналитика Телеграм-каналов" name="description"/> <meta content="Telemetr, Телеметр, телеграм-каналы, каталог телеграм каналов, аналитика телеграм-каналов" name="keywords"/> <meta content="" name="author"/> <meta content="RbZ3iXTtIa5vEjJghfLZeTQoUTLmZTmfZucbyYhC1F8x2JHiyNS1SGaefK43Rb1v" name="zen-verification"> <meta content="ed999061da5bfc79" name="yandex-verification"> <title>Telemetr - Каналы</title> <script>
#
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-MZ5MK3K');
#
#         </script> <link as="style" href="https://fonts.googleapis.com/css?family=Poppins:300,400,500,600,700|Roboto:300,400,500,600,700" rel="stylesheet preload prefetch"/> <link as="style" href="/templates/assets/vendors/general/bootstrap-select/dist/css/bootstrap-select.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/general/bootstrap-switch/dist/css/bootstrap3/bootstrap-switch.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/general/select2/dist/css/select2.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/general/socicon/css/socicon.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/custom/vendors/line-awesome/css/line-awesome.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/custom/vendors/flaticon/flaticon.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/custom/vendors/flaticon2/flaticon.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/vendors/general/@fortawesome/fontawesome-free/css/all.min.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/css/demo1/style.bundle.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/css/demo1/skins/header/base/light.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/css/demo1/skins/aside/light.css" rel="stylesheet preload prefetch"> <link as="style" href="/templates/assets/css/banner/research/research.css" rel="stylesheet preload prefetch"> <script src="/templates/jquery-3.4.1.min.js"></script> <script src="/templates/popper.min.js"></script> <script src="/templates/assets/vendors/general/bootstrap/dist/js/bootstrap.min.js"></script> <script src="/templates/assets/vendors/general/js-cookie/src/js.cookie.js"></script> <script src="/templates/assets/vendors/general/perfect-scrollbar/dist/perfect-scrollbar.js"></script> <script as="script" rel="preload" src="/templates/typeahead.bundle.min.js"></script> <script as="script" rel="preload" src="/templates/handlebars.min.js"></script> <script src="/templates/amcharts4.10.7/core.js"></script> <script src="/templates/amcharts4.10.7/charts.js"></script> <script src="/templates/amcharts4.10.7/lang/ru_RU.js"></script> <script src="/templates/amcharts4.10.7/plugins/bullets.js"></script> <script src="/templates/assets/js/banner/research/research.js"></script> <link href="/templates/my.css?v=64" media="all" rel="stylesheet" type="text/css"> <style type="text/css">
#             .kt-notification__item.bg-dark::after {
#                 display: none;
#             }
#
#             .form-control-highlighted-danger {
#                 border-color: #dc3545 !important;
#                 padding-right: 1rem;
#             background-repeat: no-repeat;
#             background-position: center right calc(0.375em + 0.325rem);
#             background-size: calc(0.75em + 0.65rem) calc(0.75em + 0.65rem);
#           }
#
#           @media (max-width: 1024px)
#           {
#               #btn_auth, #btn_reg {
#                 padding-top: 6px !important;
#               }
#           }
#
#         #confSale{
#             position: relative;
#         }
#         #confSale .closeBtnConf{
#             background-image: url("data:image/svg+xml,%3Csvg width='24' height='24' viewBox='0 0 24 24' fill='none' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath d='M6.4 19L5 17.6L10.6 12L5 6.4L6.4 5L12 10.6L17.6 5L19 6.4L13.4 12L19 17.6L17.6 19L12 13.4L6.4 19Z' fill='%239B9B9B'/%3E%3C/svg%3E%0A");
#             width: 24px;
#             height: 24px;
#             display: block;
#             position: absolute;
#             top: 2px;
#             right: 9px;
#             z-index: 20;
#         }
#
#
#         </style> <script>
#             $(document).on('click', '#button-copy-promo-code', function () {
#                 var $temp = $("<input>");
#                 $("body").append($temp);
#                 $temp.val($('#promo-code-ya-business').text()).select();
#                 document.execCommand("copy");
#                 $temp.remove();
#                 $(this).text('Тест скопирован!');
#             });
#         </script> <script src="/templates/my.js?v=91" type="text/javascript"></script> <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/> </link></link></link></link></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></head> <link as="style" href="/templates/assets/css/banner/user/user-banner.css?v=1" rel="stylesheet preload prefetch"> <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" data-banner-id="14" id="banner-user" role="dialog" tabindex="-1"> <div class="modal-dialog" role="document"> <div class="modal-content"> <div class="modal-body tx-black tx-thin"> <img alt="Telemetr" src="/public/uploads/banner/top-banner-conf-670900cc359e4.jpg" style="width: 100%;"/> </div> <button class="btn user-banner-image__close" data-do="close_user_banner"></button> <div class="modal-footer"> <a class="btn btn-success" data-do="close_user_banner" href="https://telemetr.me/purchase?utm_source=start_banner" role="button" target="_blank">
#                                 Купить подписку
#                             </a> <a class="btn btn-success" data-do="close_user_banner" href="https://telemetr.pro?utm_source=start_banner_tm" role="button" target="_blank">
#                                 О конференции
#                             </a> </div> </div> </div> </div> <body class="kt-offcanvas-panel--right kt-header--fixed kt-header-mobile--fixed kt-subheader--enabled kt-subheader--fixed kt-subheader--solid kt-page--loading kt-aside--enabled kt-aside--fixed kt-aside--minimize"> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MZ5MK3K" style="display:none;visibility:hidden" width="0"></iframe></noscript> <div id="vk_api_transport"></div> <script>
#           var pixel;
#           var pixel2;
#
#           window.vkAsyncInit = function() {
#             pixel = new VK.Pixel('VK-RTRG-174810-eeosA');
#             pixel2 = new VK.Pixel('VK-RTRG-174811-6Gx7o');
#           };
#
#           setTimeout(function() {
#             var el = document.createElement("script");
#             el.type = "text/javascript";
#             el.src = "https://vk.com/js/api/openapi.js?159";
#             el.async = true;
#             document.getElementById("vk_api_transport").appendChild(el);
#           }, 0);
#         </script> <div class="kt-header-mobile kt-header-mobile--fixed" id="kt_header_mobile"> <div class="kt-header-mobile__logo"> <a href="/"> <img class="header-logo" src="/templates/svg/logo_simple.svg" style="margin-top: -7px !important;"/> </a> </div> <ul class="kt-menu__nav"> <li class="kt-menu__item"> <form action="/analytics/" id="form_mob" method="GET"> <div class="input-group"> <input class="form-control form-control-highlighted wd-200-mob-170" id="an_channel_mob" name="name" placeholder="Введите ссылку на канал" style="border-radius: 4px 0px 0px 4px !important; border-right: 0px !important;" type="text"/> <div class="input-group-append"> <button class="btn btn-warning btn-top-analytics" type="submit"> <span class="web-hide"><i class="flaticon2-line-chart"></i></span> <span class="mobile-hide" data-do="mob_an">Анализ</span> </button> </div> </div> </form> </li> </ul> </div> <div class="kt-grid kt-grid--hor kt-grid--root"> <div class="kt-grid__item kt-grid__item--fluid kt-grid kt-grid--ver kt-page"> <div class="kt-aside kt-aside--fixed kt-grid__item kt-grid kt-grid--desktop kt-grid--hor-desktop" id="kt_aside" style="overflow-y: scroll;"> <div class="kt-aside__brand kt-grid__item" id="kt_aside_brand"> <div class="kt-aside__brand-logo"> <a href="/"> <img alt="Telemetr" class="header-logo mobile-hide" src="/templates/svg/logo_full.svg" style="margin-left: -9px; max-height: 39px !important; margin-top: -6px;"/> </a> </div> <div class="kt-aside__brand-tools"> <img class="header-logo" id="aside-logo" src="/templates/svg/logo_simple.svg" style="margin-top: -7px !important;"> </img></div> </div> <div class="kt-aside-menu-wrapper kt-grid__item kt-grid__item--fluid" id="kt_aside_menu_wrapper"> <div class="kt-aside-menu mt-0" data-ktmenu-dropdown-timeout="500" data-ktmenu-scroll="1" data-ktmenu-vertical="1" id="kt_aside_menu"> <ul class="kt-menu__nav pt-0"> <li class="kt-menu__item kt-menu__item--submenu kt-menu__item--open"> <span class="kt-menu__link kt-menu__item--active-head"> <span class="kt-menu__link-icon"><i class="flaticon-list-2"></i></span><span class="kt-menu__link-text kt-menu__item-not-link text-nowrap">Каталог каналов</span><i class="kt-menu__ver-arrow la la-angle-right"></i> </span> <div class="kt-menu__submenu"> <span class="kt-menu__arrow"></span> <ul class="kt-menu__subnav"> <li aria-haspopup="true" class="kt-menu__item kt-menu__item--active"> <a class="kt-menu__link" href="/channels/"> <span class="kt-menu__link-text text-nowrap">Поиск по каналам</span> </a> </li> <li aria-haspopup="true" class="kt-menu__item"> <a class="kt-menu__link" href="/channels/stared/"> <span class="kt-menu__link-text text-nowrap">Каналы в закладках</span> </a> </li> </ul> </div> </li> <li class="kt-menu__item kt-menu__item--submenu kt-menu__item--open"> <span class="kt-menu__link"> <span class="kt-menu__link-icon"> <i class="flaticon-notes"></i> </span> <span class="kt-menu__link-text kt-menu__item-not-link text-nowrap">Поиск постов</span><i class="kt-menu__ver-arrow la la-angle-right"></i> </span> <div class="kt-menu__submenu"> <span class="kt-menu__arrow"></span> <ul class="kt-menu__subnav"> <li aria-haspopup="true" class="kt-menu__item"> <a class="kt-menu__link" href="/posts/"> <span class="kt-menu__link-text text-nowrap">Рекламные посты</span> </a> </li> <li aria-haspopup="true" class="kt-menu__item"> <a class="kt-menu__link" href="/posts/stared/"> <span class="kt-menu__link-text text-nowrap">Посты в закладках</span> </a> </li> <li aria-haspopup="true" class="kt-menu__item"> <a class="kt-menu__link" href="/all_posts/"> <span class="kt-menu__link-text text-nowrap">Все посты</span> </a> </li> </ul> </div> </li> <li aria-haspopup="true" class="kt-menu__item"> <a class="kt-menu__link" data-boundary="window" data-placement="auto" data-toggle="kt-tooltip" href="/notifications/" title="Уведомления в телеграм о выходе новых постов с упоминанием канала или слова/фразы"> <span class="kt-menu__link-icon"> <i class="flaticon-bell-1"></i> </ ...
#
#                                                         </div> <div class="d-flex px-3"> <img alt="" class="mx-1" src="/templates/img/icons/chan.svg"/> <span class="tx-primary kt-font-bold" data-original-title="Оставшееся количество каналов для анализа на сегодняшний день" data-toggle="kt-tooltip"> 21 </span> <span class="tx-primary kt-font-bold"> / </span> <span class="tx-primary kt-font-bold" data-original-title="Общее количество каналов доступных для анализа по тарифу в день" data-toggle="kt-tooltip">25</span> </div> </div> </div> </div> </div> <div class="kt-header__topbar-item kt-header__topbar-item--user"> <div class="kt-header__topbar-wrapper" data-offset="0px,0px" data-toggle="dropdown"> <div class="kt-header__topbar-user"> <img class="mr-1 ml-1" src="/templates/pngwing.com.png"> <span class="kt-header__topbar-username mobile-hide"></span> </img></div> </div> <div class="dropdown-menu dropdown-menu-fit dropdown-menu-right dropdown-menu-anim dropdown-menu-top-unround dropdown-menu-xl"> <div class="kt-user-card kt-user-card--skin-light kt-notification-item-padding-x"> <div class="kt-user-card__avatar"> <img class="kt-hidden-" src="/templates/pngwing.com.png"> </img></div> <div class="kt-user-card__name"> <a class="__cf_email__" data-cfemail="a6edcac9d0c7cd88d2c9d6e6dfc7c8c2c3de88d4d3" href="/cdn-cgi/l/email-protection">[email protected]</a> </div> <div class="kt-user-card__badge"> <span class="btn btn-label-danger btn-sm btn-bold btn-font-md">Демо-доступ</span> </div> </div> <div class="kt-notification"> <a class="kt-notification__item" href="/profile/"> <div class="kt-notification__item-icon"> <i class="flaticon2-calendar-3 kt-font-success"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold"> Профиль </div> </div> </a> <a class="kt-notification__item header-balance-menu" href="/profile/balance/"> <div class="kt-notification__item-icon"> <i class="la la-dollar kt-font-info"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold"> Реф. баланс:  <b>0</b> руб. </div> </div> </a> <a class="kt-notification__item" href="/support/"> <div class="kt-notification__item-icon"> <i class="flaticon2-mail kt-font-warning"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold"> Поддержка </div> </div> </a> <a class="kt-notification__item bg-dark" data-do="enable_dark" href="#"> <div class="kt-notification__item-icon"> <i class="la la-moon-o kt-font-warning"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold kt-font-light"> Включить темную тему </div> </div> </a> <a class="kt-notification__item" href="https://t.me/telemetr_chat" target="_blank"> <div class="kt-notification__item-icon"> <i class="flaticon-paper-plane-1"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold"> Чат Telemetr </div> </div> </a> <a class="kt-notification__item bg-label-warning" href="/purchase/"> <div class="kt-notification__item-icon"> <i class="flaticon2-rocket-1 kt-font-danger"></i> </div> <div class="kt-notification__item-details"> <div class="kt-notification__item-title kt-font-bold kt-font-dark"> Покупка доступа </div> </div> </a> <div class="kt-notification__custom kt-space-between mb-0"> <div> <a class="btn btn-outline-brand btn-sm btn-block" href="/logout/">Выйти</a> </div> </div> </div> </div> </div> <div class="kt-header-mobile__toolbar web-hide"> <button class="btn kt-header-mobile__toggler kt-header-mobile__toggler--left pr-0 pl-0" id="kt_aside_mobile_toggler"> <i class="la la-bars kt-font-30" style="margin-top: -7px;"></i> </button> </div> </div> </div> <div class="kt-content kt-grid__item kt-grid__item--fluid kt-grid kt-grid--hor pb-2" id="kt_content"> <div class="kt-container kt-container--fluid kt-grid__item kt-grid__item--fluid"> <div class="kt-portlet" id="confSale">  ...
#
#     .chart_dark {
#         width: 100%;
#         height: 400px;
#         color: #fff;
#     }
#
#     .chart_small {
#         height: 250px;
#     }
#
#     .table th, .table td {
#         vertical-align: top !important;
#     }
#
#     .btn.btn-icon.btn-xxs {
#         width: 1.5rem !important;
#         height: 1.5rem !important;
#         margin-top: -5px !important;
#     }
#
#     .kt-ch-title {
#         font-size: 1.3rem;
#         font-weight: 500;
#     }
#
#     .tr_odd {
#         background-color: white;
#     }
#
#     .tr_even {
#         background-color: #f8f9fa;
#     }
#
#     .tr_even .select2-selection__rendered {
#         background-color: #f8f9fa;
#     }
#
#     .form-control {
#         color: black !important;
#     }
#
#     .tooltip-inner {
#         max-width: 300px !important;
#     }
#
#
#     .select2-selection__rendered, .form-control.select2-multi {
#         max-height: 40px !important;
#         overflow: scroll !important;
#     }
#
#     .select2-selection__rendered {
#         -ms-overflow-style: none; // Internet Explorer 10+
#         scrollbar-width: none; // Firefox
#     }
#
#     .select2-selection__rendered::-webkit-scrollbar {
#         display: none; // Safari and Chrome
#     }
#
#     .btn-xxs {
#         padding: 0.2em 0.3rem !important;
#     }
#
#     .t_long {
#         overflow: hidden;
#     }
#
#
#     .readmore-js-collapsed {
#         overflow: hidden;
#     }
#
#     .select2-container--default .select2-selection--multiple .select2-selection__rendered .select2-selection__choice {
#         color: #000000;
#         background: #e8ebf0;
#         border: 1px solid #ebedf2;
#         font-size: 14px;
#         cursor: pointer;
#     }
#
#     .wd-100 {
#         width: 100px;
#     }
#
#     .td-info {
#         border-bottom: 1px solid rgb(171, 168, 168);
#         border-top: 0px !important;
#         padding-top: 0px;
#     }
#
#         .td-cats .select2-selection__choice__remove {
#         display: none !important;
#     }
#
#     .select2-selection__choice {
#         cursor: pointer !important;
#     }
#
#     @media (max-width: 900px) {
#         .kt-number {
#             font-size: 1.1rem !important;
#         }
#
#         .kt-ch-title {
#             font-size: 1rem !important;
#         }
#
#         .t_long {
#             max-height: 50px !important;
#         }
#
#         .wd-50 {
#             width: 40px !important;
#         }
#
#         .td-cats {
#             padding: 5px !important;
#         }
#
#         .wd-100 {
#             padding-left: 4px !important;
#             padding-right: 2px !important;
#         }
#
#         .table th, .table td {
#             vertical-align: top !important;
#             padding-left: 4px !important;
#             padding-right: 4px !important;
#             padding-top: 3px !important;
#             padding-bottom: 0px !important;
#         }
#     }
#
#     .flaticon2-copy:hover {
#         cursor: pointer;
#     }
#
#     .clear-field {
#         margin-left: -40px;
#         z-index: 100;
#         display: none;
#         margin-right: -5px;
#     }
#
#     #thead_sticky {
#         z-index: 97 !important;
#         background-color: white;
#     }
#
#
#     .dropdown-menu-lg {
#         min-width: 300px;
#     }
#
#     .dropdown-without-caret:after {
#         content: none !important;
#     }
#
#     .select2-selection__choice__remove {
#         top: 1px !important;
#     }
#
#     .select2-container--default .select2-selection--multiple .select2-selection__rendered .select2-selection__choice {
#         font-size: 12px !important;
#     }
#
# </style> <script type="text/javascript">
#
#     console.log("javascript");
#
#     $(function () {
#         var scrw = (window.innerWidth > 0) ? window.innerWidth : screen.width;
#         var st_off = (scrw > 500) ? 65 : 50;
#
#         $('#channels_table').stickyTableHeaders({
#             fixedOffset: st_off,
#         });
#
#         var post_content_type = "feed";
#         var r = 0;
#         var last_top = 0;
#
#         updateClears();
#
#         function updateClears() {
#             $("[data-do=clearField]").each(function (k, v) {
#                 var n = $(this).prev();
#                 if ($(n).val() == "") {
#                     $(v).hide();
#                 } else {
#                     $(v).show();
#                 }
#             });
#         }
#
#         $("[data-do=clearField]").on('click', function () {
#             $(this).prev().val("");
#             $(this).hide();
#         });
#
#
#         $(document).on('propertychange change click keyup input paste', '[name=links], [name=title], [name=about], [name=participants_from], [name=participants_to], [name=views_post_from], [name=views_post_to], [name=er_from], [name=er_to], [name=mentions_week_from], [name=mentions_week_to], [name=sex_m_from], [name=sex_w_from]', function (e) {
#             updateClears();
#         });
#
#         function regen_cats() {
#             $("[data-do=show_all_cats]").remove();
#             $('.cat-group').each(function () {
#
#                 if ($(this).position().top != last_top) {
#                     var last = $(this).prev().prev();
#
#
#                     //return false;
#                     r++;
#                     if (($(window).width() <= 600 && r == 3) || ($(window).width() > 600 && r == 1)) {
#                         var more_el = $.parseHTML("<a href='#' data-do='show_all_cats'>Показать все<br></a>");
#                         $(more_el).insertBefore(last);
#                         return false;
#                     }
#
#                     last_top = $(this).position().top;
#                 }
#             });
#         }
#
#         $(window).on('resize', function () {
#             regen_cats();
#         });
#
#
#         console.log('begore regen_cats');
#         regen_cats();
#         console.log('after regen_cats');
#
#
#         console.log('before change_cats select2');
#
#         $('[data-do=change_cats]').select2({
#             createTag: function (params) {
#                 return undefined;
#             },
#             placeholder: "Категории",
#             tags: true,
#             language: "ru",
#         }).on('change', function () {
#             console.log('change_cats change');
#             var cats = $(this).val();
#             var channel_id = $(this).data('id');
#             console.log(channel_id);
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "users_cats", channel_id: channel_id, cats: cats},
#                     success: function (data) {
#                         try {
#                             console.log('try');
#                             data = $.parseJSON(data);
#                         } catch (err) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             return false;
#                         }
#                         if (data.res) {
#                         }
#                     },
#                     error: function (data) {
#                         console.log('error:');
#                     },
#                     cache: false
#                 });
#         });
#
#         console.log('after change_cats select2');
#
#         $("[data-do=show_all_cats]").on('click', function () {
#             $("[data-do=show_all_cats]").remove();
#             $(".cats_long").css('max-height', 'none').css('overflow', 'none');
#         });
#
#
#         $('#search_form').submit(function () {
#             if ($("[name=links]").val() == "") $('[name=links]').attr('name', '');
#             if ($("[name=title]").val() == "") $('[name=title]').attr('name', '');
#             if ($("[name=about]").val() == "") $('[name=about]').attr('name', '');
#             if ($("[name=participants_from]").val() == "") $('[name=participants_from]').attr('name', '');
#             if ($("[name=participants_to]").val() == "") $('[name=participants_to]').attr('name', '');
#             if ($("[name=views_post_from]").val() == "") $('[name=views_post_from]').attr('name', '');
#             if ($("[name=views_post_to]").val() == "") $('[name=views_post_to]').attr('name', '');
#             if ($("[name=er_from]").val() == "") $('[name=er_from]').attr('name', '');
#             if ($("[name=er_to]").val() == "") $('[name=er_to]').attr('name', '');
#             if ($("[name=mentions_week_from]").val() == "") $('[name=mentions_week_from]').attr('name', '');
#             if ($("[name=mentions_week_to]").val() == "") $('[name=mentions_week_to]').attr('name', '');
#             if ($("[name=sex_m_from]").val() == "") $('[name=sex_m_from]').attr('name', '');
#             if ($("[name=sex_w_from]").val() == "") $('[name=sex_w_from]').attr('name', '');
#             if ($("[name=channel_type]").val() == "all") $('[name=channel_type]').attr('name', '');
#             if ($("[name=verified]").val() == "all") $('[name=verified]').attr('name', '');
#
#                     });
#
#         $("body").on('click', ".select2-selection__choice", function () {
#             var cat = $(this).attr('title');
#             cat = cat.replace(/ \s*\(\s*\#.*\s*\)\s*/gi, '');
#             cat = cat.replace(/([\u2700-\u27BF]|[\uE000-\uF8FF]|\uD83C[\uDC00-\uDFFF]|\uD83D[\uDC00-\uDFFF]|[\u2011-\u26FF]|\uD83E[\uDD10-\uDDFF])/g, '');
#             cat = cat.replace(/%20%20/gi, '');
#             cat = cat.replace(/  /gi, '');
#             cat = cat.replace(/^%20/gi, '');
#             window.open('https://telemetr.me/channels/cat/' + cat + '/');
#             return false;
#         });
#
#
#         $('.t_long').readmore({
#             speed: 70,
#             collapsedHeight: 70,
#             lessLink: '<a href="#">свернуть</a>',
#             moreLink: '<a href="#">Показать еще...</a>',
#             collapsedClass: 'readmore-js-collapsed'
#         });
#
#         $('.kt-select2').select2({
#             minimumResultsForSearch: Infinity,
#         });
#
#         $('.kt-select2-multi').select2({
#             placeholder: "Все категории",
#             minimumResultsForSearch: Infinity,
#             closeOnSelect: false,
#             language: "ru",
#         });
#
#         window.scrollTo(0, 0);
#
#         $("[data-do=show_dynamic_participants]").on('click', function () {
#             var channel_id = $(this).data('id');
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "participants", channel_id: channel_id},
#                     success: function (data) {
#                         $(".popover").popover("hide");
#
#                         $('#modal_participants').modal('show');
#
#                         try {
#                             console.log('try');
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#                             $("#modal_participants_channel_name").html(data.channel.title);
#                             console.log('data.res');
#                             chart_participants.data = data.res;
#                             chart_participants.invalidateData();
#                         }
#                     },
#                     error: function (data) {
#                         $(".popover").popover("hide");
#                         $('#modal_participants').modal('show');
#                         console.log('error:');
#                     },
#                     cache: false
#                 });
#             return false;
#         });
#
#
#         $("[data-do=star]").on('click', function () {
#             var channel_id = $(this).data('id');
#
#             var t = $(this);
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "star", type: 'channel', id: channel_id},
#                     success: function (data) {
#                         try {
#                             console.log('try');
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#                             t.removeClass("btn-outline-warning");
#                             t.removeClass("btn-warning");
#                             if (data.res == "1") {
#                                 t.addClass("btn-warning");
#                             }
#                             if (data.res == "0") {
#                                 t.addClass("btn-outline-warning");
#                             }
#                         }
#                     },
#                     error: function (data) {
#                         console.log('error:');
#                     },
#                     cache: false
#                 });
#             return false;
#         });
#
#
#         $("body").on('shown.bs.dropdown', ".dropdown", function () {
#             var aid = $(this).data('aid');
#             console.log("shown.bs.dropdown, aid: " + aid);
#
#             if (aid !== undefined) {
#                 var t = $(this);
#                 t.find(".dropdown-menu").html('<div style="justify-content: center;" class="row p-3"><div class="kt-spinner kt-spinner--lg kt-spinner--dark"></div></div>');
#
#                 var b = $("[data-fid=" + aid + "]");
#                 b.removeClass("btn-outline-warning");
#                 b.removeClass("btn-warning");
#                 b.addClass("btn-warning");
#
#                 $.ajax(
#                     {
#                         url: '/index.php',
#                         type: "POST",
#                         data: { ajax: "fav_folders_show", aid: aid},
#                         success: function (data) {
#                             try {
#                                 data = $.parseJSON(data);
#                             } catch (e) {
#                                 console.log('catch: ' + e);
#                                 return false;
#                             }
#
#                             if (data.err) {
#                                 alert(data.err);
#                                 console.log(data.err);
#                                 return false;
#                             }
#                             if (data.res) {
#                                 t.find(".dropdown-menu").html(data.res);
#                             }
#                         },
#                         error: function (data) {
#                             console.log('error:');
#                             alert('Произошла неизвестная ошибка! Попробуйте еще раз.');
#                         },
#                         cache: false
#                     });
#             }
#         });
#
#
#         function fav_add(aid, folder) {
#             console.log("fav_add | aid: " + aid + " | folder: " + folder);
#
#             var t = $("[data-fid=" + aid + "]");
#
#             t.removeClass("btn-outline-warning");
#             t.removeClass("btn-warning");
#             t.addClass("btn-warning");
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "fav_add", aid: aid, folder: folder},
#                     success: function (data) {
#                         try {
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#
#                         }
#                     },
#                     error: function (data) {
#                         console.log('error:');
#                         alert('Произошла неизвестная ошибка! Попробуйте еще раз.');
#                     },
#                     cache: false
#                 });
#         }
#
#         function fav_remove(aid) {
#             console.log("fav_remove | ad_id: " + aid);
#
#             var t = $("[data-fid=" + aid + "]");
#
#             t.removeClass("btn-outline-warning");
#             t.removeClass("btn-warning");
#             t.addClass("btn-outline-warning");
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "fav_remove", aid: aid},
#                     success: function (data) {
#                         try {
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#
#                         }
#                     },
#                     error: function (data) {
#                         console.log('error:');
#                         alert('Произошла неизвестная ошибка! Попробуйте еще раз.');
#                     },
#                     cache: false
#                 });
#         }
#
#
#         $("body").on('click', "[data-do=fav_folder_change]", function (e) {
#             e.preventDefault();
#             var aid = $(this).data('aid');
#             var folder = $(this).data('folder');
#             console.log('fav_folder_change clicked: ' + aid);
#             fav_add(aid, folder);
#         });
#
#         $("body").on('click', "[data-do=fav_folder_delete]", function (e) {
#             e.preventDefault();
#             var aid = $(this).data('aid');
#             console.log('fav_folder_delete clicked: ' + aid);
#             fav_remove(aid);
#         });
#
#         $("body").on('click', "[data-do=fav_folder_new]", function (e) {
#             e.preventDefault();
#             var aid = $(this).data('aid');
#             var folder = $(this).parent().parent().find("input").val();
#             console.log('fav_folder_new clicked: ' + aid + ' | folder: ' + folder);
#             fav_add(aid, folder);
#         });
#
#         $(document).on('mouseenter', '[data-do=show_about]', function (event) {
#             console.log("data-info mouseenter");
#             var t = $(this);
#             var name = $(this).data('info');
#             var e = $(this);
#             var cont = $(this).data('cont');
#
#             $(".popover").popover("hide");
#
#             $(document).on('mouseleave', ".popover-body", function () {
#                 console.log("     .popover-body mouseleave");
#
#                 clearTimeout(popover_timeout);
#
#                 e.popover('hide');
#             });
#
#             e.popover({
#                 content: cont,
#                 html: true,
#                 placement: "top",
#                 container: "body",
#                 boundary: "window",
#                 trigger: 'manual',
#                 animation: false,
#                 skin: 'dark',
#                 delay: {
#                     hide: 50
#                 }
#             }).on('mouseenter', function () {
#
#             }).on('mouseleave', function () {
#                 var _this = this;
#                 popover_timeout = setTimeout(function () {
#                     if (!$('.popover:hover').length) {
#                         console.log('hide popover');
#                         $(_this).popover('hide');
#                         clearTimeout(popover_timeout);
#                     }
#                 }, 100);
#             });
#
#             e.popover('show');
#             $(document).on('mouseleave', ".tooltip-body", function () {
#                 console.log("     .tooltip-body mouseleave");
#                 clearTimeout(popover_timeout);
#                 e.popover('hide');
#             });
#
#             return false;
#         });
#
#
#         $("[data-do=show_dynamic_views]").on('click', function () {
#             var channel_id = $(this).data('id');
#
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: { ajax: "views", channel_id: channel_id},
#                     success: function (data) {
#                         $(".popover").popover("hide");
#                         $('#modal_views').modal('show');
#
#                         try {
#                             console.log('try');
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#                             $("#modal_views_channel_name").html(data.channel.title);
#                             console.log('data.res');
#                             chart_views.data = data.res;
#                             chart_views.invalidateData();
#                         }
#                     },
#                     error: function (data) {
#                         $(".popover").popover("hide");
#                         $('#modal_views').modal('show');
#                         console.log('error:');
#                     },
#                     cache: false
#                 });
#             return false;
#         });
#
#
#
#
#
#
#         $(document).on('click', "[data-do=show_content]", function () {
#             $("#modal_content_tabs").hide();
#             var type = $(this).data('type');
#             var cid = $(this).data('cid');
#
#             $("#modal_content_channel_name").html("Загрузка...");
#             $("#modal_content").find(".modal-body").html('<div style="justify-content: center;" class="row p-3"><div class="kt-spinner kt-spinner--lg kt-spinner--dark"></div></div>');
#
#             if (type !== undefined) {
#                 console.log('type!==undefined, post_content_type=' + type);
#                 post_content_type = type;
#             }
#
#
#             if (post_content_type == "feed") {
#                 $("#modal_content").find(".modal-dialog").removeClass("modal-md").removeClass("modal-lg").addClass("modal-md");
#                 $("[data-do=show_content][data-type=list]").removeClass("active");
#                 $("[data-do=show_content][data-type=feed]").addClass("active");
#             }
#
#             if (post_content_type == "list") {
#                 $("#modal_content").find(".modal-dialog").removeClass("modal-md").removeClass("modal-lg").addClass("modal-lg");
#                 $("[data-do=show_content][data-type=list]").addClass("active");
#                 $("[data-do=show_content][data-type=feed]").removeClass("active");
#             }
#             console.log('show_content | cid: ' + cid + ' | type: ' + type + ' | post_content_type: ' + post_content_type);
#
#             if ($(this).data('type') === undefined) {
#                 $(".popover").popover("hide");
#                 reopenModal('modal_content');
#             }
#
#             $.ajax(
#                 {
#                     url: '/index.php',
#                     type: "POST",
#                     data: {
#                         ajax: "channel_content", cid: cid, type: post_content_type
#                     },
#                     success: function (data) {
#                         try {
#                             console.log('try');
#                             data = $.parseJSON(data);
#                         } catch (e) {
#                             console.log('catch');
#                             return false;
#                         }
#
#                         if (data.err) {
#                             console.log('data.err');
#                             return false;
#                         }
#                         if (data.res) {
#                             $("[data-do=show_content][data-type=feed]").attr('data-cid', data.cid);
#                             $("[data-do=show_content][data-type=list]").attr('data-cid', data.cid);
#
#                             $("#modal_content_tabs").show();
#                             $("#modal_content_channel_name").html(data.channel.title);
#                             $("#modal_content").find(".modal-body").html(data.res);
#                             update_cats_select();
#                         }
#                     },
#                     error: function (data) {
#
#                         console.log('error:');
#                     },
#                     cache: false
#                 });
#             return false;
#         });
#
#
#         $("[data-do=show_filters]").on('click', function () {
#             $("#do_search_cats").hide();
#             $("#search_filters").show().removeClass("mobile-hide");
#             $("[data-do=show_filters]").hide();
#
#             $('.kt-select2').select2({
#                 minimumResultsForSearch: Infinity,
#             });
#
#             return false;
#         });
#
#
#         $(document).on('click', "[data-do=copy_link]", function () {
#             var link = $(this).data('link');
#             copyToClipboard(link);
#             console.log('copied link ' + link);
#             $("#div_popover_copy").html("Ссылка скопирована в буфер!");
#             return false;
#         });
#
#         function copyToClipboard(copy_text) {
#             var $temp = $("<input>");
#             $("body").append($temp);
#             $temp.val(copy_text).select();
#             document.execCommand("copy");
#             $temp.remove();
#         }
#
#
#         $(document).on('mouseenter', ".cat-group", function () {
#             $(this).find("[data-do=combine_cats]").show();
#         });
#
#         $(document).on('mouseleave', ".cat-group", function () {
#             $(this).find("[data-do=combine_cats]").hide();
#         });
#
#
#         $("th.sortable").on('click', function (e) {
#             console.log("th sortable click, event_target: ", e.target.tagName);
#             if (e.target.tagName != "A" && e.target.tagName != "I") {
#                 e.stopPropagation();
#                 $(this).find(".dropdown-toggle").dropdown('toggle');
#                 return false;
#             }
#         });
#
#         console.log("before amcharts ready");
#
#
#         var chart_participants;
#         var chart_views;
#         am4core.ready(function () {
#             	chart_participants = am4core.create("chart_participants", am4charts.XYChart);
# 	chart_participants.data = [];
#
# 	categoryAxis_chart_participants = chart_participants.xAxes.push(new am4charts.CategoryAxis());
# 	categoryAxis_chart_participants.dataFields.category = "day";
# 	categoryAxis_chart_participants.renderer.grid.template.disabled = true;
# let chart_participants_watermark = new am4core.Image();
# chart_participants_watermark.href = "/templates/svg/logo_full.svg";
# chart_participants.plotContainer.children.push(chart_participants_watermark);
# chart_participants_watermark.align = "left";
# chart_participants_watermark.valign = "top";
# chart_participants_watermark.width = 100;
# chart_participants_watermark.opacity = 0.8;
# chart_participants_watermark.marginLeft = 10;
# chart_participants_watermark.marginTop = -10;
# chart_participants_watermark.zIndex = 5;
# chart_participants_watermark.heightRatio = 0.3;	categoryAxis_chart_participants.adapter.add("getTooltipText", (text, target) => {
# 	 return ">>> " + text + " <<<";
# 	});
#
# 	/* Create value axis */
# 	var valueAxis = chart_participants.yAxes.push(new am4charts.ValueAxis());
# 	valueAxis.renderer.grid.template.disabled = true;	valueAxis.min = 0;	var series0 = chart_participants.series.push(new am4charts.LineSeries());
# 	series0.dataFields.categoryX = "day";
# 	series0.name = "Подписчиков";
# 	series0.dataFields.valueY = "participants";
# 	series0.fillOpacity = 0.5;
# 	series0.strokeWidth = 2;
#
# 	var fillModifier = new am4core.LinearGradientModifier();
# 	fillModifier.opacities = [1, 0];
# 	fillModifier.offsets = [0, 1];
# 	fillModifier.gradient.rotation = 90;
# 	series0.segments.template.fillModifier = fillModifier;
# 	series0.adapter.add("tooltipHTML", function(ev) {
# 	    return "<span style='text-align: center; font-weight: bold;'>Подписчиков</span>: <span style='font-size: 18px;''>{participants}</span>";
# 	  });
#
# 	//series0.tooltipHTML = `<span style='text-align: center; font-weight: bold;'>Подписчиков</span>: <span style='font-size: 18px;''>{participants}</span>`;
# 	series0.tooltip.getFillFromObject = false;
# 	series0.tooltip.background.fill = am4core.color("#ffb822");
# 	series0.tooltip.label.fill = am4core.color("#000000");
# 	series0.tooltip.background.strokeWidth = 0;
# 	series0.tooltip.background.filters.clear();
# 	chart_participants.events.on("datavalidated", function(ev) {
# 		//console.log('chart_participants datavalidated');
# 	});
#
# 	var cursor_chart_participants = new am4charts.XYCursor();
# 	chart_participants.cursor = cursor_chart_participants;
# 	chart_participants.cursor.maxTooltipDistance = 0;;
#             	chart_views = am4core.create("chart_views", am4charts.XYChart);
# 	chart_views.data = [];
#
# 	categoryAxis_chart_views = chart_views.xAxes.push(new am4charts.CategoryAxis());
# 	categoryAxis_chart_views.dataFields.category = "day";
# 	categoryAxis_chart_views.renderer.grid.template.disabled = true;
# let chart_views_watermark = new am4core.Image();
# chart_views_watermark.href = "/templates/svg/logo_full.svg";
# chart_views.plotContainer.children.push(chart_views_watermark);
# chart_views_watermark.align = "left";
# chart_views_watermark.valign = "top";
# chart_views_watermark.width = 100;
# chart_views_watermark.opacity = 0.8;
# chart_views_watermark.marginLeft = 10;
# chart_views_watermark.marginTop = -10;
# chart_views_watermark.zIndex = 5;
# chart_views_watermark.heightRatio = 0.3;	categoryAxis_chart_views.adapter.add("getTooltipText", (text, target) => {
# 	 return ">>> " + text + " <<<";
# 	});
#
# 	/* Create value axis */
# 	var valueAxis = chart_views.yAxes.push(new am4charts.ValueAxis());
# 	valueAxis.renderer.grid.template.disabled = true;	valueAxis.min = 0;	var series0 = chart_views.series.push(new am4charts.LineSeries());
# 	series0.dataFields.categoryX = "day";
# 	series0.name = "Просмотров";
# 	series0.dataFields.valueY = "views";
# 	series0.fillOpacity = 0.5;
# 	series0.strokeWidth = 2;
#
# 	var fillModifier = new am4core.LinearGradientModifier();
# 	fillModifier.opacities = [1, 0];
# 	fillModifier.offsets = [0, 1];
# 	fillModifier.gradient.rotation = 90;
# 	series0.segments.template.fillModifier = fillModifier;
# 	series0.adapter.add("tooltipHTML", function(ev) {
# 	    return "<span style='text-align: center; font-weight: bold;'>Просмотров</span>: <span style='font-size: 18px;''>{views}</span>";
# 	  });
#
# ...
# 									Описание
# 								</span> <button class="btn btn-outline-warning kt-font-dark btn-icon btn-sm btn-icon-md btn-circle mobile-hide" data-cid="1430572621" data-do="show_content" data-toggle="kt-tooltip" href="#" title="Показать контент канала" type="button"><i class="fl flaticon-layers"></i></button> <a class="btn btn-sm btn-xs a_icon_black" data-boundary="window" data-container="body" data-do="copy_link" data-html="true" data-link="https://t.me/psymems" data-toggle="kt-tooltip" href="#" title="&lt;div id='div_popover_copy'&gt;Скопировать прямую ссылку на канал&lt;/div&gt;"> <i class="fl flaticon2-copy"></i> </a> </div> </td> <td class="text-nowrap pb-0"> <span class="kt-number kt-font-brand text-cursor" data-boundary="window" data-do="show_dynamic_participants" data-id="1430572621" data-toggle="kt-tooltip" title="Показать график динамики числа подписчиков канала">
# 								2'658
# 							</span> </td> <td class="text-nowrap pb-0"> <span class="kt-number kt-font-danger">-2</span>
#                 сегодня
#
#             /
#
#
#                             <span class="kt-number kt-number-small kt-font-danger">-2</span>
#                 вчера
#
#             <div class="" style="height: 5px;"></div> <span class="kt-number kt-number-small kt-font-danger">-4</span>
#                 за неделю
#
#                             <br/> <span class="kt-number kt-number-small kt-font-success"> +18</span>
#                     за месяц
#                                     </td> <td class="text-nowrap pb-0"> <span class="kt-number kt-font-brand text-cursor" data-boundary="window" data-do="show_dynamic_views" data-html="true" data-id="1430572621" data-toggle="kt-tooltip" title="Среднее количество просмотров публикации за последнюю неделю.&lt;br&gt;&lt;br&gt; Кликните, чтобы посмотреть график."> 649 </span> <br/> <span class="kt-number kt-number-small kt-font-brand" data-toggle="kt-tooltip" title="Среднее количество просмотров на пост за вчера"> 646 </span>
#                 вчера
#
#         </td> <td class="pb-0"> <span class="kt-number kt-font-brand" data-boundary="window" data-container="body" data-toggle="kt-tooltip" title="ER - отношение количества реакций (просмотров поста) к общему количеству подписчиков. Чем больше - тем лучше.">
# 								39.2%
# 								</span> </td> <td class="pb-0 text-nowrap"> <i class="fa fa-refresh" data-boundary="window" data-toggle="kt-tooltip" title="Владелец канала еще не проанализировал аудиторию канала с помощью соответствующего инструмента."></i> </td> <td class="pb-0"> </td> <td class="text-nowrap pb-0"> <span class="kt-number kt-font-brand" data-boundary="window" data-toggle="kt-tooltip" title="Количество репостов\упоминаний канала в других каналах за последние 7 дней."> <a href="/posts/?mentions=https://t.me/psymems&amp;date_from=2024-10-08 21:53:37" target="_blank">1</a> </span>
#                 за неделю
#
#
#             <br/> <span class="kt-number kt-number-small kt-font-brand" data-boundary="window" data-toggle="kt-tooltip" title="Количество репостов\упоминаний канала в других каналах за последние 30 дней"> <a href="/posts/?mentions=https://t.me/psymems&amp;date_from=2024-09-15 21:53:37" target="_blank">2</a> </span>
#                 за месяц
#
#
#             <br/> <span class="kt-number kt-number-small kt-font-brand" data-boundary="window" data-toggle="kt-tooltip" title="Количество репостов\упоминаний канала в других каналах за все время"> <a href="/posts/?mentions=https://t.me/psymems" target="_blank">144</a> </span>
#                 всего
#                     </td> </tr> <tr class="tr_odd"> <td class="pd-0-force td-info pt-1 td-cats" colspan="12" data-boundary="window" data-container="body" data-toggle="kt-tooltip" data-trigger="focus" title="Вы можете предложить свои категории для канала. После выбора вами нужных категорий они будут отправлены на проверку и после нее станут доступны всем."> <div class="web-hide pb-2"> <a class="btn btn-label-facebook btn-sm pl-2 pr-2 pt-1 pb-1 kt-font-12" href="/channels/cat/Юмор/" target="_blank">Юмор
#                                     (<b>#1338</b>)</a> </div> <div class="mobile-hide"> <select class="form-control select2-multi mt-1" data-boundary="window" data-container="body" data-do="change_cats" data-id="1430572621" data-toggle="kt-tooltip" data-trigger="focus" multiple="" name="param" style="display: none;" title="Вы можете предложить свои категории для канала"> <option data-n="1" value="GIF и video">GIF и video </option> <option data-n="1" value="IT">IT </option> <option data-n="1" value="SMM">SMM </option> <option data-n="1" value="Авто и мото">Авто и мото </option> <option data-n="1" value="Авторский блог">Авторский блог </option> <option data-n="1" value="Азербайджанские каналы">Азербайджанские каналы </option> <option data-n="1" value="Активный отдых">Активный отдых </option> <option data-n="1" value="Анекдоты">Анекдоты </option> <option data-n="1" value="Аниме">Аниме </option> <option data-n="1" value="Армянские каналы">Армянские каналы </option> <option data-n="1" value="Афиша">Афиша </option> <option data-n="1" value="Белорусские каналы">🇧🇾  Белорусские каналы </option> <option data-n="1" value="Бизнес и финансы">Бизнес и финансы </option> <option data-n="1" value="Блогеры">Блогеры </option> <option data-n="1" value="Вакансии">Вакансии </option> <option data-n="1" value="Военное">Военное </option> <option data-n="1" value="Все подряд">Все подряд </option> <option data-n="1" value="Гороскоп">Гороскоп </option> <option data-n="1" value="Грузинские каналы">Грузинские каналы </option> <option data-n="1" value="Даркнет">Даркнет </option> <option data-n="1" value="Дизайн">Дизайн </option> <option data-n="1" value="Для мужчин">Для мужчин </option> <option data-n="1" value="Для родителей">Для родителей </option> <option data-n="1" value="ЕГЭ и экзамены">ЕГЭ и экзамены </option> <option data-n="1" value="Женские">Женские </option> <option data-n="1" value="Животные">Животные </option> <option data-n="1" value="Здоровье">Здоровье </option> <option data-n="1" value="Знакомства">Знакомства </option> <option data-n="1" value="Игры">Игры </option> <option data-n="1" value="Искусство">Искусство </option> <option data-n="1" value="Казахстанские каналы">🇰🇿  Казахстанские каналы </option> <option data-n="1" value="Карьера">Карьера </option> <option data-n="1" value="Каталог">Каталог </option> <option data-n="1" value="Киргизские каналы">🇰🇬  Киргизские каналы </option> <option data-n="1" value="Коронавирус">Коронавирус </option> <option data-n="1" value="Красота и мода">Красота и мода </option> <option data-n="1" value="Криптовалюты">Криптовалюты </option> <option data-n="1" value="Кулинария">Кулинария </option> <option data-n="1" value="Лайфхаки">Лайфхаки </option> <option data-n="1" value="Лингвистика">Лингвистика </option> <option data-n="1" value="Литература">Литература </option> <option data-n="1" value="Магазин">Магазин </option> <option data-n="1" value="Маркетплейсы">Маркетплейсы </option> <option data-n="1" value="Мобайл">Мобайл </option> <option data-n="1" value="Молдавские каналы">Молдавские каналы </option> <option data-n="1" value="Музыка">Музыка </option> <option data-n="1" value="Наука и технологии">Наука и технологии </option> <option data-n="1" value="Недвижимость">Недвижимость </option> <option data-n="1" value="Новости">Новости </option> <option data-n="1" value="Образование">Образование </option> <option data-n="1" value="Объявления">Объявления </option> <option data-n="1" value="Однострочные">Однострочные </option> <option data-n="1" value="Подкасты">Подкасты </option> <option data-n="1" value="Подслушано">Подслушано </option> <option data-n="1" value="Познавательные">Познавательные </option> <option data-n="1" value="Политика">Политика </option> <option data-n="1" value="Пошлое">Пошлое </option> <option data-n="1" value="Прогнозы и ставки">Прогнозы и ставки </option> <option data-n="1" value="Прокси">Прокси </option> <option data-n="1" value="Психология">Психология </option> <option data-n="1" value="Путеше ...
#                                     <b>#1338</b>
#                                     )</option> <option data-n="1" value="Юриспруденция">Юриспруденция </option> </select> </div> </td> </tr> </tbody> <thead> <tr class="th_header text-center"> <th> </th> <th> <div class="p-2">
# 								Название
# 							</div> </th> <th class="p-0 m-0 bg-secondary"> <div class="p-2">
#     							Подписчики
#                             </div> </th> <th class="text-nowrap p-0 m-0"> <div class="p-2">
#                                 Сегодня / вчера / за неделю / месяц
#                             </div> </th> <th class="p-0 m-0 text-nowrap"> <div class="p-2"> <i class="fa fa-eye"></i> на пост / вчера
#                             </div> </th> <th class="p-0 m-0 text-nowrap"> <div class="p-2">
#                                 ER
#                             </div> </th> <th class="p-0 m-0 text-nowrap"> <div class="p-2">
#                                 Пол М/Ж
#                             </div> </th> <th class="p-0 m-0 text-nowrap"> <div class="p-2">
#                                 За пост
#                             </div> </th> <th class="p-0 m-0 text-nowrap"> <div class="p-2"> <i class="fa fa-retweet"></i> сегодня / неделя
#                             </div> </th> </tr> </thead> </table> </div> </div> <div class="kt-pagination"> <ul class="kt-pagination__links"> <li> <a class="btn-light" href="/channels/cat/Юмор/?order_column=participants_count&amp;order_direction=DESC&amp;page=1&amp;participants_from=500&amp;participants_to=3000&amp;lang_ru=1&amp;lang_uz=0&amp;channel_type=all&amp;moderate=all&amp;verified=all&amp;detailed_bot_added=all&amp;lang_code=any">1</a> </li> <li class="kt-pagination__link--active"> <a class="btn btn-warning disabled kt-font-dark disabled" href="#">2</a> </li> <li> <a class="btn-light" href="/channels/cat/Юмор/?order_column=participants_count&amp;order_direction=DESC&amp;page=3&amp;participants_from=500&amp;participants_to=3000&amp;lang_ru=1&amp;lang_uz=0&amp;channel_type=all&amp;moderate=all&amp;verified=all&amp;detailed_bot_added=all&amp;lang_code=any">3</a> </li> <li> <a class="btn-light" href="/channels/cat/Юмор/?order_column=participants_count&amp;order_direction=DESC&amp;page=4&amp;participants_from=500&amp;participants_to=3000&amp;lang_ru=1&amp;lang_uz=0&amp;channel_type=all&amp;moderate=all&amp;verified=all&amp;detailed_bot_added=all&amp;lang_code=any">4</a> </li> <li> <a class="btn btn-light disabled" href="#">...</a> </li> <li> <a class="btn-light" href="/channels/cat/Юмор/?order_column=participants_count&amp;order_direction=DESC&amp;page=5&amp;participants_from=500&amp;participants_to=3000&amp;lang_ru=1&amp;lang_uz=0&amp;channel_type=all&amp;moderate=all&amp;verified=all&amp;detailed_bot_added=all&amp;lang_code=any">5</a> </li> <li> <span class="btn btn-light disabled pagination_limit">Показано 5 страниц поисковой выдачи. Больше данных в <a href="/premium/">платной подписке</a></span> </li> </ul> <div class="kt-pagination__toolbar mobile-hide"> <h4 class="mobile-hide">
# 		 		Найдено <span class="kt-number kt-font-brand">797</span> каналов
# 		 		 с аудиторией в <span class="kt-number kt-font-brand">1'138'008</span> подписчиков		 	</h4> </div> <div class="kt-pagination__toolbar web-hide"> <span class="kt-number kt-font-brand">797</span> каналов
#
#         </div> </div> </link></div> </div> <div class="kt-footer kt-grid__item kt-grid kt-grid--desktop kt-grid--ver-desktop" id="kt_footer"> <div class="kt-container kt-container--fluid"> <div class="kt-footer__copyright">2017-2024 © <a class="kt-link" href="https://telemetr.me" target="_blank">Telemetr.me</a></div> <div class="kt-footer__menu"> <a class="kt-footer__menu-link kt-link" href="/support/" target="_blank">Поддержка</a> <a class="kt-footer__menu-link kt-link" href="/terms-of-services/" target="_blank">Пользовательское соглашение</a> <a class="kt-footer__menu-link kt-link" href="/privacy-policy/" target="_blank">Политика конфиденциальности</a> <a class="kt-footer__menu-link kt-link" href="/oferta/" target="_blank">Публичная оферта</a> </div> </div> </div> <script type="text/javascript">
#
#     $("[data-do=show_modal_elama_support]").on('click', function () {
#         $('#modal_elama_support').modal('show');
#
#         return false;
#     });
#
# </script> </div> </div> </div> <script type="text/javascript">
#             jQuery(document).ready(function() {
#
#
#                           });
#         </script> <script type="text/javascript">
#             (function(m, e, t, r, i, k, a) {
#                 m[i] = m[i] || function() {
#                     (m[i].a = m[i].a || []).push(arguments)
#                 };
#                 m[i].l = 1 * new Date();
#                 for(var j = 0; j < document.scripts.length; j++) {
#                     if(document.scripts[j].src === r) {
#                         return;
#                     }
#                 }
#                 k = e.createElement(t), a = e.getElementsByTagName(t)[0], k.async = 1, k.src = r, a.parentNode.insertBefore(k, a)
#             })(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#             ym(46317153, "init", {
#                 clickmap: true,
#                 trackLinks: true,
#                 accurateTrackBounce: true,
#                 webvisor: true
#             });
#         </script> <noscript> <div><img alt="" src="https://mc.yandex.ru/watch/46317153" style="position:absolute; left:-9999px;"/></div> </noscript> <script>
#         window.replainSettings = { id: 'fc2e2d9f-f3b3-4b94-bd9c-e46ff9b171bf' };
#         (function(u){var s=document.createElement('script');s.async=true;s.src=u;
#         var x=document.getElementsByTagName('script')[0];x.parentNode.insertBefore(s,x);
#         })('https://widget.replain.cc/dist/client.js');
#     </script> <script>
#         $('body').on('click', '.closeBtnConf', function(){
#             $('#confSale').fadeOut()
#             setTimeout(()=>{
#                 $('#confSale').remove()
#             }, 1000)
#         })
#     </script> <div class="research-image" style="display: none;"> <a class="research-image__main" href="https://telemetr.me/research2024?utm_source=telemetr_web" target="_blank"> <img alt="" class="research-image__main-img" src="/templates/images/research.jpg" width="453"/> </a> <button class="btn research-image__close"></button> </div> <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'8d32034bb86e0031',t:'MTcyOTAxODQxNy4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body> </link></html>
